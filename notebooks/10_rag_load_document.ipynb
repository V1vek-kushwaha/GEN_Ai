# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/speech.txt")




text = loader.load()

onedoc = text[0]
onedoc.page_content
# Out:
# 'hello im am vivek '

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/YT_Script_Audio_PRO.pdf")
docs = loader.load()
len(docs)
onedoc = docs[0]
print(onedoc.page_content)

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader("../data/Statement_1765383220904.csv")

docs = loader.load()

onedoc = docs[0]
print(onedoc.page_content)

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://docs.langchain.com/oss/python/integrations/providers/overview")


docs = loader.load()

onedoc = docs[0]

print(onedoc.page_content)

# %% [markdown]
# #wikipedia loader

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query= "gen ai",load_max_docs=1)

docs = loader.load()
print(docs)
