# %%
from dotenv import load_dotenv
load_dotenv()

# %%
# from langchain_groq import ChatGroq
# llm = ChatGroq(model="openai/gpt-oss-120b",streaming=True)
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

qustion = "explain me what is gen ai ?"

res = llm.stream(qustion)
for chunk in res:
    print(chunk.content ,end="")
# Out:
# Let's break down **Generative AI (Gen AI)** in a way that's easy to understand.
#
# Imagine you have a very creative and skilled artist or writer. This artist can look at a vast collection of existing art or writing, learn the patterns, styles, and nuances, and then **create something entirely new** based on that knowledge.
#
# **Generative AI is essentially that creative artist, but in the digital world.** It's a type of artificial intelligence that's designed to **generate new content**, rather than just analyze or classify existing data.
#
# Here's a more structured explanation:
#
# **The Core Idea: Creation, Not Just Analysis**
#
# *   **Traditional AI (Discriminative AI):** Think of this as an AI that's good at *identifying* or *classifying*. For example, it can tell you if an image is a cat or a dog, or if a piece of text is positive or negative sentiment. It learns to *discriminate* between different categories.
# *   **Generative AI:** This AI goes a step further. It learns the underlying patterns and structures of data so well that it can **produce new data that resembles the original data but is entirely novel.**
#
# **How Does it Work (Simplified)?**
#
# Gen AI models are trained on massive datasets. These datasets can include:
#
# *   **Text:** Books, articles, websites, code.
# *   **Images:** Photographs, paintings, illustrations.
# *   **Audio:** Music, speech.
# *   **Video:** Movies, clips.
# *   **Code:** Programming languages.
#
# During training, the AI learns:
#
# *   **Relationships:** How words relate to each other, how colors and shapes form objects, how musical notes create melodies.
# *   **Patterns:** The grammar of language, the style of an artist, the structure of a song.
# *   **Context:** The meaning behind words, the mood of an image.
#
# Once trained, when you give it a **prompt** (an instruction or a question), it uses its learned knowledge to generate a response.
#
# **What Can Generative AI Create?**
#
# The possibilities are vast and growing rapidly:
#
# *   **Text:**
#     *   Writing stories, poems, scripts.
#     *   Summarizing long documents.
#     *   Translating languages.
#     *   Answering questions conversationally.
#     *   Generating different creative text formats (like code, scripts, musical pieces, email, letters, etc.).
#     *   Writing emails, blog posts, marketing copy.
# *   **Images:**
#     *   Creating realistic or artistic images from text descriptions.
#     *   Editing existing images (e.g., changing styles, adding elements).
#     *   Generating entirely new artwork.
# *   **Audio:**
#     *   Composing music.
#     *   Generating realistic human-like speech.
#     *   Creating sound effects.
# *   **Video:**
#     *   Generating short video clips from text.
#     *   Animating images.
# *   **Code:**
#     *   Writing code snippets.
#     *   Debugging code.
#     *   Translating code between languages.
#
# **Key Types of Generative AI Models:**
#
# You might hear about specific types of Gen AI, such as:
#
# *   **Large Language Models (LLMs):** These are the engines behind many text-based Gen AI tools (like ChatGPT, Bard/Gemini). They are trained on enormous amounts of text data.
# *   **Diffusion Models:** These are very popular for image generation (like Midjourney, Stable Diffusion, DALL-E). They work by gradually adding noise to an image and then learning to reverse that process to create new images.
# *   **Generative Adversarial Networks (GANs):** An earlier but still important architecture where two neural networks (a generator and a discriminator) compete to create realistic data.
#
# **Why is it a Big Deal?**
#
# Generative AI is transformative because it:
#
# *   **Democratizes Creativity:** Makes it easier for people without specialized skills to create complex content.
# *   **Boosts Productivity:** Automates tasks that were previously time-consuming and labor-intensive.
# *   **Unlocks New Possibilities:** Enables entirely new forms of art, entertainment, and problem-solving.
# *   **Accelerates Innovation:** Can help researchers and developers by generating hypotheses, code, and designs.
#
# **Important Considerations:**
#
# While exciting, Gen AI also brings challenges:
#
# *   **Accuracy and Hallucinations:** Models can sometimes generate incorrect or nonsensical information ("hallucinations").
# *   **Bias:** The data these models are trained on can contain biases, which can be reflected in the generated content.
# *   **Ethics and Misinformation:** The ability to create realistic fake content raises concerns about misinformation and deepfakes.
# *   **Copyright and Ownership:** Questions arise about who owns the copyright of AI-generated content.
#
# **In a nutshell, Generative AI is about teaching computers to be creators. It's a powerful tool that's changing how we interact with technology and what we can achieve with it.**
