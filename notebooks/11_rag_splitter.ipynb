# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_text_splitters import RecursiveCharacterTextSplitter
text = "bilkul FREE tools se, apni raw audio ko PRO level pe kaise le jaaye. Aur \
haan — ye tricks wahi hain jo MrBeast ke audio engineers use karte hain. Toh bana rahe — \
kyunki ye video tumhare channel ki life badal sakti hai! n \
Agar tumare audio mein ye teen problems hain — toh chill karo, aaj sab fix ho jaayega. "


splitter = RecursiveCharacterTextSplitter(chunk_size = 50 , chunk_overlap = 10)

chunks = splitter.split_text(text)
chunks

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/speech.txt")

data = loader.load()

onedoc = data[0]

# onedoc.page_content


short = splitter.split_text(onedoc.page_content)

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/YT_Script_Audio_PRO.pdf")

data = loader.load()


spliteText = splitter.split_documents(data)

spliteText
