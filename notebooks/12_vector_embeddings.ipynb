# %%
from dotenv import load_dotenv
load_dotenv()

# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2")

vector = embeddings.embed_documents(documents)

len(vector)


## store vector embeddings in vector db



from langchain_chroma import Chroma

vector_store = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
    )

quary = "machine learnings"

result = vector_store.similarity_search(query=quary , k=2)

print(result)
# Out:
# [Document(id='c3ae4738-fc02-4618-8a3d-3a3577ba4a3d', metadata={}, page_content='Machine learning is a subset of artificial intelligence'), Document(id='d10b1cdf-d081-4400-8935-98889f53fd36', metadata={}, page_content='Machine learning is a subset of artificial intelligence')]
